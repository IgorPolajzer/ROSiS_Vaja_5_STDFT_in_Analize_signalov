# %% [markdown]
# # STDFT in Analize signalov

# %%
from importlib import reload
from util import *
from stdft import stdft

import util

reload(util)


FILES = ["sig1.csv", "sig2.csv", "sig3.csv"]
interval = 1
overlap = 0.0
hamming = True

for file in FILES:
    file = f"/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_5/naloga_1_rpm/{file}"
    fr, ti, sp = stdft(file, interval, overlap, hamming_window=hamming)
    calculate_rpm(sp, fr)
    plot_spectogram(fr, ti, sp, file, interval, overlap, hamming)
# Out:
# Dominant Frequency: 30.0
# Rpm: 1800.0
# Dominant Frequency: 38.5
# Rpm: 2310.0
# Dominant Frequency: 38.75
# Rpm: 2325.0
